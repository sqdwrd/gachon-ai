# %%
import pandas as pd
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.calibration import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("~/dev/gachon-ai/datasets/heart.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
y = df["target"]
x = df.drop("target", axis=1)

# %%
Y = pd.get_dummies(y).values

# %%
X_train, X_test, y_train, y_test = train_test_split(x, Y, test_size=0.2, random_state=0)

# %%
X_train.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 74    43    0   2       122   213    0        1      165      0      0.2
# 153   66    0   2       146   278    0        0      152      0      0.0
# 64    58    1   2       140   211    1        0      165      0      0.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 287   57    1   1       154   232    0        0      164      0      0.0
#
#      slope  ca  thal
# 74       1   0     2
# 153      1   1     2
# 64       2   0     2
# 296      1   0     2
# 287      2   1     2

# %%
y_test
# Out:
# array([[ True, False],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [False,  True]])

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((242, 13), (61, 13), (242, 2), (61, 2))

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(20,input_shape=(13,),activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(2,activation='sigmoid'))

model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 20)                280
#
#  dense_5 (Dense)             (None, 20)                420
#
#  dense_6 (Dense)             (None, 20)                420
#
#  dense_7 (Dense)             (None, 2)                 42
#
# =================================================================
# Total params: 1,162
# Trainable params: 1,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 0s 10ms/step - loss: 17.4666 - accuracy: 0.4628 - val_loss: 11.2941 - val_accuracy: 0.4426
# Epoch 2/30
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3413 - accuracy: 0.4587 - val_loss: 4.7746 - val_accuracy: 0.4426
# Epoch 3/30
# 8/8 [==============================] - 0s 2ms/step - loss: 3.7061 - accuracy: 0.5000 - val_loss: 1.5840 - val_accuracy: 0.6885
# Epoch 4/30
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2966 - accuracy: 0.6116 - val_loss: 1.2259 - val_accuracy: 0.6721
# Epoch 5/30
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2273 - accuracy: 0.6281 - val_loss: 0.8965 - val_accuracy: 0.7377
# Epoch 6/30
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0402 - accuracy: 0.6736 - val_loss: 0.7580 - val_accuracy: 0.7049
# Epoch 7/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8911 - accuracy: 0.6777 - val_loss: 0.7800 - val_accuracy: 0.6393
# Epoch 8/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9019 - accuracy: 0.6240 - val_loss: 0.7601 - val_accuracy: 0.6557
# Epoch 9/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8661 - accuracy: 0.6694 - val_loss: 0.6967 - val_accuracy: 0.7049
# Epoch 10/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8267 - accuracy: 0.6570 - val_loss: 0.7189 - val_accuracy: 0.6721
# Epoch 11/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7942 - accuracy: 0.6818 - val_loss: 0.6833 - val_accuracy: 0.7049
# Epoch 12/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7821 - accuracy: 0.6694 - val_loss: 0.7027 - val_accuracy: 0.6557
# Epoch 13/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7748 - accuracy: 0.6612 - val_loss: 0.6663 - val_accuracy: 0.6885
# Epoch 14/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7457 - accuracy: 0.6818 - val_loss: 0.6740 - val_accuracy: 0.6393
# Epoch 15/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7374 - accuracy: 0.6653 - val_loss: 0.6583 - val_accuracy: 0.6885
# Epoch 16/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7395 - accuracy: 0.6488 - val_loss: 0.6556 - val_accuracy: 0.6557
# Epoch 17/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7200 - accuracy: 0.6694 - val_loss: 0.6519 - val_accuracy: 0.6230
# Epoch 18/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7002 - accuracy: 0.6488 - val_loss: 0.6532 - val_accuracy: 0.6393
# Epoch 19/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6879 - accuracy: 0.6777 - val_loss: 0.6311 - val_accuracy: 0.6885
# Epoch 20/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.6942 - val_loss: 0.6323 - val_accuracy: 0.6393
# Epoch 21/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.6322 - val_loss: 0.6184 - val_accuracy: 0.6721
# Epoch 22/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6714 - accuracy: 0.6777 - val_loss: 0.6116 - val_accuracy: 0.6721
# Epoch 23/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6629 - accuracy: 0.6777 - val_loss: 0.6077 - val_accuracy: 0.6721
# Epoch 24/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.6488 - val_loss: 0.5995 - val_accuracy: 0.6885
# Epoch 25/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6611 - accuracy: 0.6570 - val_loss: 0.6115 - val_accuracy: 0.6721
# Epoch 26/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6786 - accuracy: 0.6240 - val_loss: 0.5970 - val_accuracy: 0.6885
# Epoch 27/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6567 - accuracy: 0.6653 - val_loss: 0.6143 - val_accuracy: 0.7049
# Epoch 28/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6424 - accuracy: 0.6694 - val_loss: 0.5865 - val_accuracy: 0.6885
# Epoch 29/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.6736 - val_loss: 0.5849 - val_accuracy: 0.6721
# Epoch 30/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6387 - accuracy: 0.6488 - val_loss: 0.5980 - val_accuracy: 0.7049
# 2/2 [==============================] - 0s 793us/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
